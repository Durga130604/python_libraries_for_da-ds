# %%
#math functions
import numpy as np
a=np.arange(0,6)
print(np.sqrt(a))
print(np.exp(a))
print(np.max(a))
print(a.max())
# Out:
# [0.         1.         1.41421356 1.73205081 2.         2.23606798]
# [  1.           2.71828183   7.3890561   20.08553692  54.59815003
#  148.4131591 ]
# 5
# 5
