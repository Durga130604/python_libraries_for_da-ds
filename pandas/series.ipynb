# %%
# DAY-1 / 11-FEB 2026

import pandas as pd
first_series=pd.Series([2,4,6,8])
print(first_series)
#print(first_series[-1])  not working

number_series=pd.Series([2,3,5,6,8],index=['a','b','d','e','f'],name='Number')
print(number_series)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64
# a    2
# b    3
# d    5
# e    6
# f    8
# Name: Number, dtype: int64

# %%
number_series=pd.Series([2,3,5,6,8],index=['a','b','d','e','f'],name='Number')
#print(number_series[-1]) 
print(number_series['e'])
# Out:
# 6
