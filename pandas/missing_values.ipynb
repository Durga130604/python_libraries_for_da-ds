# %% [markdown]
# CALCULATIONS WITH MISSING VALUES --

# %%
#24-FEB
import pandas as pd
import numpy as np
df=pd.DataFrame({'A':[1,2,np.nan],'B':['a',np.nan,'c'],'C':[10,np.nan,np.nan]})
print(df)
# Out:
#      A    B     C
# 0  1.0    a  10.0
# 1  2.0  NaN   NaN
# 2  NaN    c   NaN

# %%
#isnull()
print(df['A'].isnull())
# Out:
# 0    False
# 1    False
# 2     True
# Name: A, dtype: bool

# %%
#ISNULL()
#NOTNULL()
df=pd.DataFrame(np.random.randn(5,3),index=['a','b','c','d','e'],columns=['one','two','three'])
print(df)
df=df.reindex(['p','b','c','d','q'])
print(df.isnull())
print(df.notnull())
# Out:
#         one       two     three
# a -0.363884 -0.335853 -1.611582
# b  0.730690 -1.391420 -1.269513
# c  1.782106  0.190313  0.739957
# d -1.330532 -0.061400 -0.765338
# e -2.074958 -1.204099 -1.259711
#      one    two  three
# p   True   True   True
# b  False  False  False
# c  False  False  False
# d  False  False  False
# q   True   True   True
#      one    two  three
# p  False  False  False
# b   True   True   True
# c   True   True   True
# d   True   True   True
# q  False  False  False

# %%
#SUM()
import pandas as pd
import numpy as np
df=pd.DataFrame({'A':[1,2,np.nan],'B':['a',np.nan,'c'],'C':[10,np.nan,np.nan]})
print(df)
print(df['A'].sum())
print(df['B'].sum())
print(df['C'].sum())
# Out:
#      A    B     C
# 0  1.0    a  10.0
# 1  2.0  NaN   NaN
# 2  NaN    c   NaN
# 3.0
# ac
# 10.0

# %%
#COUNT()
print(df['A'].count())
print(df['B'].count())
print(df['C'].count())
print(df.value_counts())   # returns the count of not null row wise
print(df.count())          # counts ths not null column wise
# Out:
# 2
# 2
# 1
# A    B  C
# 1.0  a  10.0    1
# Name: count, dtype: int64
# A    2
# B    2
# C    1
# dtype: int64

# %%
# FILL()
df=pd.DataFrame({'A':[1,2,3],'B':['a',np.nan,'c'],'C':[10,np.nan,20]})
df1=df.fillna(value='Cat')
print(df1)
# Out:
#    A    B     C
# 0  1    a  10.0
# 1  2  Cat   Cat
# 2  3    c  20.0

# %%
#DROPNA()
df=pd.DataFrame({'A':[1,2,3],'B':['a',np.nan,'c'],'C':[10,np.nan,np.nan]})
print(df)
print(df.dropna())
# Out:
#    A    B     C
# 0  1    a  10.0
# 1  2  NaN   NaN
# 2  3    c   NaN
#    A  B     C
# 0  1  a  10.0

# %%
#25-FEB
#fillna()
df=pd.DataFrame({'A':[1,2,3],'B':['a',np.nan,'c'],'C':[10,np.nan,np.nan]})
print(df.fillna(3))
# Out:
#    A  B     C
# 0  1  a  10.0
# 1  2  3   3.0
# 2  3  c   3.0

# %%
#filling mean or sum values of the column in place of nan 
print(df['A'].fillna(value=df['A'].mean()))
print(df['A'].fillna(value=df['A'].sum()))
# Out:
# 0    1
# 1    2
# 2    3
# Name: A, dtype: int64
# 0    1
# 1    2
# 2    3
# Name: A, dtype: int64

# %%
#print(df.fillna(value=df['A'].mean()))
print(df.fillna(value=df['C'].mean()))
# Out:
#    A     B     C
# 0  1     a  10.0
# 1  2  10.0  10.0
# 2  3     c  10.0

# %%
#thresh() with drop()  thresh- counts least not null value in a column to remove 
df=pd.DataFrame({'A':[1,2,np.nan],'B':[4,5,10],'C':[10,np.nan,np.nan]})
print(df,"\n\n")
print(df.dropna(thresh=2))
# Out:
#      A   B     C
# 0  1.0   4  10.0
# 1  2.0   5   NaN
# 2  NaN  10   NaN
#
#
#      A  B     C
# 0  1.0  4  10.0
# 1  2.0  5   NaN

# %%
#REPLACE FUNC
df=pd.DataFrame({'one':[10,20,30,40,50,2000], 'two':[1000,0,30,20,40,50]})
print(df,"\n\n")
print(df.replace({1000:10,2000:0}))
# Out:
#     one   two
# 0    10  1000
# 1    20     0
# 2    30    30
# 3    40    20
# 4    50    40
# 5  2000    50
#
#
#    one  two
# 0   10   10
# 1   20    0
# 2   30   30
# 3   40   20
# 4   50   40
# 5    0   50

# %% [markdown]
# GROUPBY()
# 1. aggregation   - computing a summary statics
# 2. transformation  - perform some group-specific operation
# 3. filteration   - discarding the data with some condition

# %%
import pandas as pd
ipl_data={'Team':['Riders','Riders','Devils','Devils','Kings','Kings','Kings','Kings','Riders','Royals','Royals','Riders'],
          'Rank':[1,2,2,3,3,4,1,1,2,4,1,2],
          'Year':[2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
          'points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)
print(df)
# Out:
#       Team  Rank  Year  points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
#Splitting data into groups
df1=df.groupby('Year').groups
print(df1,"\n\n")
df2=df.groupby('Team').groups
print(df2,"\n\n")
df3=df.groupby('Rank').groups
print(df3)
# Out:
# {2014: [0, 2, 4, 9], 2015: [1, 3, 5, 10], 2016: [6, 8], 2017: [7, 11]}
#
#
# {'Devils': [2, 3], 'Kings': [4, 5, 6, 7], 'Riders': [0, 1, 8, 11], 'Royals': [9, 10]}
#
#
# {1: [0, 6, 7, 10], 2: [1, 2, 8, 11], 3: [3, 4], 4: [5, 9]}

# %%
#df1=df.groupby('Team').max()
#print(df1, "\n\n")
df2=df.groupby('Year').max()
print(df2)

# %%
# 26-FEB
import pandas as pd
ipl_data={'Team':['Riders','Riders','Devils','Devils','Kings','Kings','Kings','Kings','Riders','Royals','Royals','Riders'],
          'Rank':[1,2,2,3,3,4,1,1,2,4,1,2],
          'Year':[2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
          'points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)
df1=df.groupby('Team').max()['points']
print(df1)
# Out:
# Team
# Devils    863
# Kings     812
# Riders    876
# Royals    804
# Name: points, dtype: int64

# %%
df1=df.groupby('Year')['Rank'].mean()
print(df1)
df2=df.groupby('Year')['Rank'].count()
print(df2)
df3=df.groupby('Year')['Rank'].sum()
print(df3)
df4=df.groupby('Year')['Rank'].std()
print(df4)
# Out:
# Year
# 2014    2.5
# 2015    2.5
# 2016    1.5
# 2017    1.5
# Name: Rank, dtype: float64
# Year
# 2014    4
# 2015    4
# 2016    2
# 2017    2
# Name: Rank, dtype: int64
# Year
# 2014    10
# 2015    10
# 2016     3
# 2017     3
# Name: Rank, dtype: int64
# Year
# 2014    1.290994
# 2015    1.290994
# 2016    0.707107
# 2017    0.707107
# Name: Rank, dtype: float64

# %%
df1=df.groupby('Year')['Rank'].agg(["std","mean","max"])
print(df1)
# Out:
#            std  mean  max
# Year
# 2014  1.290994   2.5    4
# 2015  1.290994   2.5    4
# 2016  0.707107   1.5    2
# 2017  0.707107   1.5    2

# %%
#score=lambda x:(x+10)
grouped=df.groupby('Team')
score=lambda x: (x+10)               #adding 10 to each rank, eg: 1+10 =11 
print(grouped.transform(score))
# Out:
#     Rank  Year  points
# 0     11  2024     886
# 1     12  2025     799
# 2     12  2024     873
# 3     13  2025     683
# 4     13  2024     751
# 5     14  2025     822
# 6     11  2026     766
# 7     11  2027     798
# 8     12  2026     704
# 9     14  2024     711
# 10    11  2025     814
# 11    12  2027     700

# %%
grouped=df.groupby('Team')
score=lambda x: (x+10)               #adding 10 to each rank, eg: 1+10 =11 
print(grouped['points'].transform(score))
# Out:
# 0     886
# 1     799
# 2     873
# 3     683
# 4     751
# 5     822
# 6     766
# 7     798
# 8     704
# 9     711
# 10    814
# 11    700
# Name: points, dtype: int64

# %%
#team count should be 3  more than 3
print(df.groupby('Team').filter(lambda x: len(x) >= 3))
# Out:
#       Team  Rank  Year  points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 11  Riders     2  2017     690

# %%
#27-FEB
import pandas as pd
df=pd.read_csv("C:\\Users\\Lenovo\\downloads\\imdb_data.csv",encoding='latin-1') #encoding='utf-8'
print(df)
# Out:
#       ï»¿id                              belongs_to_collection    budget  \
# 0         1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1         2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2         3                                                NaN   3300000
# 3         4                                                NaN   1200000
# 4         5                                                NaN         0
# ...     ...                                                ...       ...
# 2995   2996                                                NaN         0
# 2996   2997                                                NaN         0
# 2997   2998                                                NaN  65000000
# 2998   2999                                                NaN  42000000
# 2999   3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.shape
# Out:
# (3000, 23)

# %%
df.describe()
# Out:
#              ï»¿id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
# 3rd movie details
df.iloc[2]
# Out:
# ï»¿id                                                                    3
# belongs_to_collection                                                  NaN
# budget                                                             3300000
# genres                                       [{'id': 18, 'name': 'Drama'}]
# homepage                                 http://sonyclassics.com/whiplash/
# imdb_id                                                          tt2582802
# original_language                                                       en
# original_title                                                    Whiplash
# overview                 Under the direction of a ruthless instructor, ...
# popularity                                                        64.29999
# poster_path                               /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg
# production_companies     [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# ...

# %%
# specific detail 
df.iloc[2]['original_title']
# Out:
# 'Whiplash'

# %%
#specific detail 
df.iloc[6]['original_title']
# Out:
# 'The Possession'

# %%
#specific detail 
df.iloc[9]['original_title']
# Out:
# 'A Mighty Wind'

# %%
#9-MAR
import pandas as pd
df.sort_values('revenue',ascending=False)[['title','revenue']].head(1)
# Out:
#              title     revenue
# 1126  The Avengers  1519557910

# %%
df.sort_values('revenue',ascending=False)[['title','revenue']].iloc[1]
# Out:
# title       Furious 7
# revenue    1506249360
# Name: 1761, dtype: object

# %%
#df.isnull()['keywords'].value_counts()
#df['keywords'].isnull().values_counts()

# %%
#what is the average revenue of movies
print(df['revenue'].mean())
# Out:
# 66725851.88866667

# %%
print(df['runtime'].mean())
# Out:
# 107.85657104736491

# %%
#what is the average revenue of movie released 
df.groupby('status')[['revenue','title']].max()
# Out:
#              revenue                                           title
# status
# Released  1519557910                                  ÐÐ¾ÑÐ¾Ð»ÑÐ²
# Rumored     13418091  The Swan Princess: Escape from Castle Mountain

# %%
#to change the format of date column

df['release_date'] = pd.to_datetime(df['release_date'])
df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15540\3090522062.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['release_date'] = pd.to_datetime(df['release_date'])
#       ï»¿id                              belongs_to_collection    budget  \
# 0         1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1         2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2         3                                                NaN   3300000
# 3         4                                                NaN   1200000
# 4         5                                                NaN         0
# ...     ...                                                ...       ...
# 2995   2996                                                NaN         0
# 2996   2997                                                NaN         0
# ...

# %%
#first and last movie released
df.sort_values('release_date')[['title','release_date']].iloc[[0,-1]]
# Out:
#                  title release_date
# 1480  Sunset Boulevard   1950-08-10
# 1336   Rooster Cogburn   2075-10-17

# %%
# 11- MAR
import pandas as pd
df=pd.read_csv("C:\\Users\\Lenovo\\downloads\\ds_salaries.csv",encoding='latin-1') #encoding='utf-8'
print(df)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df.shape
# Out:
# (607, 12)

# %%
df.info() # to get all information
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    str
#  3   employment_type     607 non-null    str
#  4   job_title           607 non-null    str
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    str
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    str
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    str
#  11  company_size        607 non-null    str
# dtypes: int64(5), str(7)
# memory usage: 57.0 KB

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
#find out the avg salary
print(df['salary'].mean())
# Out:
# 324000.0626029654

# %%
# find the max salary 

print(df.groupby('employment_type')['salary'].max())
# Out:
# employment_type
# CT      416000
# FL      100000
# FT    30400000
# PT      400000
# Name: salary, dtype: int64

# %%
# count the no. of employee in each employment_type
print(df.groupby('employment_type')['job_title'].count())
#df['employment_type'].value_counts()
# Out:
# employment_type
# CT      5
# FL      4
# FT    588
# PT     10
# Name: job_title, dtype: int64

# %%
# unique job names and total how any unique jobs
print(df['job_title'].unique())
df['job_title'].nunique()
# Out:
# <StringArray>
# [                          'Data Scientist',
#                'Machine Learning Scientist',
#                         'Big Data Engineer',
#                      'Product Data Analyst',
#                 'Machine Learning Engineer',
#                              'Data Analyst',
#                       'Lead Data Scientist',
#                     'Business Data Analyst',
#                        'Lead Data Engineer',
#                         'Lead Data Analyst',
#                             'Data Engineer',
#                   'Data Science Consultant',
#                           'BI Data Analyst',
#                  'Director of Data Science',
#                        'Research Scientist',
#                  'Machine Learning Manager',
#                  'Data Engineering Manager',
#  'Machine Learning Infrastructure Engineer',
#                               'ML Engineer',
#                              'AI Scientist',
# ...

# %%
# top 2 most common jobs
df['job_title'].value_counts().head(2)
# Out:
# job_title
# Data Scientist    143
# Data Engineer     132
# Name: count, dtype: int64

# %%
# all rows with true and false
df['job_title']=='AI Scientist'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 602    False
# 603    False
# 604    False
# 605    False
# 606     True
# Name: job_title, Length: 607, dtype: bool

# %%
# rows only with the match
df[df['job_title']=='AI Scientist']
# Out:
#      Unnamed: 0  work_year experience_level employment_type     job_title  \
# 52           52       2020               EN              FT  AI Scientist
# 96           96       2021               EN              PT  AI Scientist
# 113         113       2021               EN              PT  AI Scientist
# 244         244       2021               EN              FT  AI Scientist
# 277         277       2021               SE              FT  AI Scientist
# 391         391       2022               MI              FT  AI Scientist
# 606         606       2022               MI              FT  AI Scientist
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 52    300000             DKK          45896                 DK            50
# 96     12000             USD          12000                 BR           100
# 113    12000             USD          12000                 PK           100
# ...

# %%
# heighest salary of AI Scientist
print(df[df['job_title']=='AI Scientist']['salary'].max())
# Out:
# 1335000

# %%
# heighest salary of AI Scientist with their job_title
print(df[df['job_title']=='AI Scientist'][['salary','job_title']].max())
# Out:
# salary            1335000
# job_title    AI Scientist
# dtype: object

# %%
# how many job titles are in 2020
df[df['work_year']==2020]['job_title'].count()
# Out:
# np.int64(72)

# %%
# display years
df['work_year'].unique()
# Out:
# array([2020, 2021, 2022])

# %%
# each year how many emp
df['work_year'].value_counts()
# Out:
# work_year
# 2022    318
# 2021    217
# 2020     72
# Name: count, dtype: int64

# %%
# how many emp in US
df[df['company_location']=='US'][['company_location','job_title']].count()
# Out:
# company_location    355
# job_title           355
# dtype: int64

# %%
df['company_location'].
# Out:
# company_location
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# PK      3
# AE      3
# MX      3
# DK      3
# LU      3
# BR      3
# TR      3
# AU      3
# CN      2
# NG      2
# IT      2
# BE      2
# RU      2
# SI      2
# CH      2
# CZ      2
# HN      1
# HU      1
# NZ      1
# HR      1
# SG      1
# RO      1
# IQ      1
# UA      1
# IL      1
# MT      1
# CL      1
# IR      1
# CO      1
# MD      1
# KE      1
# VN      1
# AS      1
# DZ      1
# EE      1
# MY      1
# IE      1
# Name: count, dtype: int64
