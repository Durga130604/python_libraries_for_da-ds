# %% [markdown]
# DAY-2/ 12-FEB 2026

# %%
import pandas as pd
number_series=pd.Series([2,3,5,6,8],index=['a','b','d','e','f'],name='Number')
#print(number_series[-1]) 
print(number_series['b'])
# Out:
# 3

# %%
import pandas as pd
number1_series=pd.Series([2,3,5,6,10],index=['a','b','d','e','f'],name='value')
print(number1_series['f'])
# Out:
# 10

# %%
import pandas as pd
number1_series=pd.Series([2,3,5,6,10],index=['a','b','d','e','f'],name='value')
print(number1_series['a'])
# Out:
# 2

# %%
import pandas as pd
number1_series=pd.Series([2,3,5,6,10],index=['a','b','d','e','f'],name='value')
print(number1_series['b'])
# Out:
# 3
